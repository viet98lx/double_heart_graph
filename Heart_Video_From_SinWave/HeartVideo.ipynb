# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function f(x)
def f(x, a):
    return np.abs(x)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x**2) * np.sin(a * np.pi * x)

def f2(x, a):
    x_new = x-0.75
    return np.abs(x_new)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x_new**2) * np.sin(a * np.pi * x_new)

# Define the range of x values
x = np.linspace(-np.sqrt(np.pi), np.sqrt(np.pi), 400)
x2 = np.linspace(-np.sqrt(np.pi)-0.25, np.sqrt(np.pi)+1, 400)
# Set the value of a
a = 15

# Compute the y values
y = f(x, a)
y2 = f2(x2, a)
# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x, y, label=f'a={a}')
plt.plot(x2, y2)

# Add labels and title
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of f(x) for a=10')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/c1/gtzhpfkx4552rv7rfl4spv0m0000gn/T/ipykernel_15433/387241722.py:10: RuntimeWarning: invalid value encountered in sqrt
#   return np.abs(x_new)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x_new**2) * np.sin(a * np.pi * x_new)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function f(x)
def f(x, a):
    # Define the valid function for the range -sqrt(pi) to sqrt(pi)
    f_valid = np.abs(x)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x**2) * np.sin(a * np.pi * x)
    
    # Calculate the values at the boundaries
    boundary_value_pos = np.abs(np.sqrt(np.pi))**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - np.sqrt(np.pi)**2) * np.sin(a * np.pi * np.sqrt(np.pi))
    boundary_value_neg = np.abs(-np.sqrt(np.pi))**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - (-np.sqrt(np.pi))**2) * np.sin(a * np.pi * -np.sqrt(np.pi))
    
    # Initialize the result array with zeros
    y = np.zeros_like(x)
    
    # Apply the valid function within the range -sqrt(pi) to sqrt(pi)
    valid_mask = (x >= -np.sqrt(np.pi)) & (x <= np.sqrt(np.pi))
    y[valid_mask] = f_valid[valid_mask]
    
    # Apply the boundary values outside the valid range
    y[x > np.sqrt(np.pi)] = boundary_value_pos
    y[x < -np.sqrt(np.pi)] = boundary_value_neg
    
    return y

def double_heart_f(x, a, shift=0.5):
    # Define the valid function for the range -sqrt(pi) to sqrt(pi)
    f_valid = np.abs(x)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x**2) * np.sin(a * np.pi * x)
    x2 = x-shift
    f_valid_2 = np.abs(x2)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x2**2) * np.sin(a * np.pi * x2)

    x_boundary = np.sqrt(np.pi)
    # Calculate the values at the boundaries
    boundary_value_pos = np.abs(x_boundary)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x_boundary**2) * np.sin(a * np.pi * x_boundary)
    boundary_value_neg = np.abs(-x_boundary)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - (-x_boundary)**2) * np.sin(a * np.pi * -x_boundary)

    # x_boundary_2 = np.sqrt(np.pi)-shift
    # boundary_value_pos_2 = np.abs(x_boundary_2)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x_boundary_2**2) * np.sin(a * np.pi * x_boundary_2)
    # boundary_value_neg_2 = np.abs(-x_boundary_2)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - (-x_boundary_2)**2) * np.sin(a * np.pi * -x_boundary_2)
    
    # Initialize the result array with zeros
    y = np.zeros_like(x)
    y2 = np.zeros_like(x)
    
    # Apply the valid function within the range -sqrt(pi) to sqrt(pi)
    valid_mask = (x >= -np.sqrt(np.pi)) & (x <= np.sqrt(np.pi))
    valid_mask_2 = (x2 >= -np.sqrt(np.pi)) & (x2 <= np.sqrt(np.pi))
    y[valid_mask] = f_valid[valid_mask]
    y2[valid_mask_2] = f_valid_2[valid_mask_2]
    
    
    # Apply the boundary values outside the valid range
    y[x > np.sqrt(np.pi)] = boundary_value_pos
    y[x < -np.sqrt(np.pi)] = boundary_value_neg
    y2[x2 > np.sqrt(np.pi)] = boundary_value_pos
    y2[x2 < -np.sqrt(np.pi)] = boundary_value_neg
    return y, y2

# Define the range of x values
x = np.linspace(-2, 3, 400)

# Set the value of a
a = 10

# Compute the y values
y, y2 = double_heart_f(x, a, shift=0.75)

# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x, y, label=f'a={a}')
plt.plot(x, y2, label=f'a={a}')

# Add labels and title
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of f(x) for a=10')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/c1/gtzhpfkx4552rv7rfl4spv0m0000gn/T/ipykernel_15433/2743153804.py:28: RuntimeWarning: invalid value encountered in sqrt
#   f_valid = np.abs(x)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x**2) * np.sin(a * np.pi * x)
# /var/folders/c1/gtzhpfkx4552rv7rfl4spv0m0000gn/T/ipykernel_15433/2743153804.py:30: RuntimeWarning: invalid value encountered in sqrt
#   f_valid_2 = np.abs(x2)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x2**2) * np.sin(a * np.pi * x2)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import Video

# Configure matplotlib to use ffmpeg
plt.rcParams['animation.writer'] = 'ffmpeg'

# Define the function f(x, a)
def f(x, a):
    f_valid = np.abs(x)**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - x**2) * np.sin(a * np.pi * x)
    boundary_value_pos = np.abs(np.sqrt(np.pi))**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - np.sqrt(np.pi)**2) * np.sin(a * np.pi * np.sqrt(np.pi))
    boundary_value_neg = np.abs(-np.sqrt(np.pi))**(2/3) + (np.exp(1)/3) * np.sqrt(np.pi - (-np.sqrt(np.pi))**2) * np.sin(a * np.pi * -np.sqrt(np.pi))
    y = np.zeros_like(x)
    valid_mask = (x >= -np.sqrt(np.pi)) & (x <= np.sqrt(np.pi))
    y[valid_mask] = f_valid[valid_mask]
    y[x > np.sqrt(np.pi)] = boundary_value_pos
    y[x < -np.sqrt(np.pi)] = boundary_value_neg
    return y

def double_heart_f(x, a, shift=0.5, param_1=2/3, param_2=np.exp(1)/3, param_3=np.pi, param_4=1):
    # Define the valid function for the range -sqrt(pi) to sqrt(pi)
    f_valid = np.abs(x)**(param_1) + param_2 * np.sqrt(param_3 - param_4*x**2) * np.sin(a * np.pi * x)
    x2 = x-shift
    f_valid_2 = np.abs(x2)**(param_1) + param_2 * np.sqrt(param_3 - param_4*x2**2) * np.sin(a * np.pi * x2)

    x_boundary = np.sqrt(np.pi)
    # Calculate the values at the boundaries
    boundary_value_pos = np.abs(x_boundary)**(2/3) + param_2 * np.sqrt(param_3 - param_4*x_boundary**2) * np.sin(a * np.pi * x_boundary)
    boundary_value_neg = np.abs(-x_boundary)**(2/3) + param_2 * np.sqrt(param_3 - (-param_4*x_boundary)**2) * np.sin(a * np.pi * -x_boundary)


    # Initialize the result array with zeros
    y = np.zeros_like(x)
    y2 = np.zeros_like(x)
    
    # Apply the valid function within the range -sqrt(pi) to sqrt(pi)
    valid_mask = (x >= -np.sqrt(np.pi)) & (x <= np.sqrt(np.pi))
    valid_mask_2 = (x2 >= -np.sqrt(np.pi)) & (x2 <= np.sqrt(np.pi))
    y[valid_mask] = f_valid[valid_mask]
    y2[valid_mask_2] = f_valid_2[valid_mask_2]
    
    
    # Apply the boundary values outside the valid range
    y[x > np.sqrt(np.pi)] = boundary_value_pos
    y[x < -np.sqrt(np.pi)] = boundary_value_neg
    y2[x2 > np.sqrt(np.pi)] = boundary_value_pos
    y2[x2 < -np.sqrt(np.pi)] = boundary_value_neg
    return y, y2


# Define the range of x values
x = np.linspace(-2, 3, 400)

# Define the range of values for parameter a
a_values = np.linspace(1.5, 20, 300)

# Initialize the plot
fig, ax = plt.subplots(figsize=(10, 6))
line, = ax.plot([], [], 'blue', lw=2)
line2, = ax.plot([], [], 'orange', lw=2)
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_title('♡')
ax.set_xlim(-2, 2)
ax.set_ylim(-2.2, 3)

# Function to update the plot for each frame of the animation
def update(frame):
    a = a_values[frame]
    y, y2 = double_heart_f(x, a, shift=0.1, param_1=2/3, param_2=np.exp(1)/3, param_3=np.pi, param_4=1)
    line.set_data(x, y)
    line2.set_data(x, y2)
    ax.set_title('♡')
    return line,

# Create the animation
ani = FuncAnimation(fig, update, frames=len(a_values), interval=100, blit=True)

# Save the animation as an mp4 file
ani.save('animation.mp4', writer='ffmpeg')

# Display the saved mp4 animation in the notebook
Video('animation.mp4')
# Out:
# <div id='01e13262-59c5-4ec4-813b-1276819b3d00'></div>
# /var/folders/c1/gtzhpfkx4552rv7rfl4spv0m0000gn/T/ipykernel_15433/1473171060.py:24: RuntimeWarning: invalid value encountered in sqrt
#   f_valid = np.abs(x)**(param_1) + param_2 * np.sqrt(param_3 - param_4*x**2) * np.sin(a * np.pi * x)
# /var/folders/c1/gtzhpfkx4552rv7rfl4spv0m0000gn/T/ipykernel_15433/1473171060.py:26: RuntimeWarning: invalid value encountered in sqrt
#   f_valid_2 = np.abs(x2)**(param_1) + param_2 * np.sqrt(param_3 - param_4*x2**2) * np.sin(a * np.pi * x2)
# <video src="animation.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
